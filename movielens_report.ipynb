# %% [markdown]
# ### **Inputs**

# %%
# %load_ext autoreload
# %aimport movielens_analysis
# %autoreload

# %% [markdown]
# ## **Links**

# %% [markdown]
# 0. Parsing asked data from **IMDB**:

# %%
links = movielens_analysis.Links('../datasets/links.csv')
movie_ids = list(links.movie_ids)[:10]
fields = ['Title', 'Release Date', 'Rating', 'Director', 'Budget', 'Cumulative Worldwide Gross', 'Runtime']
# %timeit links.get_imdb(movie_ids, fields)
links.get_imdb(movie_ids, fields)
# Out:
# [[10,
#   'Золотой глаз',
#   'January 19, 1996 (Russia)',
#   7.2,
#   'Martin Campbell',
#   60000000,
#   352194034,
#   130],
#  [9,
#   'Внeзапная смерть',
#   'December 22, 1995 (United States)',
#   5.9,
#   'Peter Hyams',
#   35000000,
#   64350171,
#   111],
#  [8,
#   'Приключения Тома Сойера',
#   'December 22, 1995 (United States)',
#   5.5,
#   'Peter Hewitt',
#   'N/A',
#   23920048,
#   97],
#  [7,
#   'Сабрина',
#   'December 15, 1995 (United States)',
#   6.3,
#   'Sydney Pollack',
#   58000000,
#   53696959,
#   127],
#  [6,
#   'Схватка',
#   'March 16, 1996 (Russia)',
#   8.3,
#   'Michael Mann',
#   60000000,
#   187436818,
#   170],
#  [5,
#   'Отец невесты 2',
#   'December 8, 1995 (United States)',
#   6.1,
#   'Charles Shyer',
#   30000000,
#   76594107,
#   106],
#  [4,
#   'В ожидании выдоха',
#   'December 22, 1995 (United States)',
#   6.0,
#   'Forest Whitaker',
#   16000000,
#   81452156,
#   124],
#  [3,
#   'Старые ворчуны разбушевались',
# ...

# %% [markdown]
# and **TMDB**:

# %%
links = movielens_analysis.Links('../datasets/links.csv')
movie_ids = list(links.movie_ids)[:10]
fields = ['Title', 'Release Date', 'Genres', 'Director', 'Cast', 'Budget', 'Cumulative Worldwide Gross', 'Runtime']
# %timeit links.get_tmdb(movie_ids, fields)
links.get_tmdb(movie_ids, fields)
# Out:
# Error fetching data for movie ID 1: HTTPSConnectionPool(host='www.themoviedb.org', port=443): Max retries exceeded with url: /movie/862 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000021820FE42C0>: Failed to establish a new connection: [WinError 10061] Подключение не установлено, т.к. конечный компьютер отверг запрос на подключение'))
# Error fetching data for movie ID 2: HTTPSConnectionPool(host='www.themoviedb.org', port=443): Max retries exceeded with url: /movie/8844 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002181F3586B0>: Failed to establish a new connection: [WinError 10061] Подключение не установлено, т.к. конечный компьютер отверг запрос на подключение'))
# ...

# %% [markdown]
# 1.  Get top-n directors by number of movies in the form:
#
# `{'director': number of movies created by them}`.
#
# > Sorted descendingly.

# %%
n = 5
# %timeit links.top_directors(n)
print(links.top_directors(n))

# %% [markdown]
# 2. Get top-n movies by budgets in the form:
#
# `{'movie title': budget}`.
#
# > Sorted descendingly.

# %%
n = 5
# %timeit links.most_expensive(n)
print(links.most_expensive(n))

# %% [markdown]
# 3. Get top-n movies by profit in the form:
#
# `{'movie title': profit}`.
#
# > Sorted descendingly.

# %%
n = 5
# %timeit links.most_profitable(n)
print(links.most_profitable(n))
# Out:
# 22 s ± 1.37 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# {'Toy Story': 364436586, 'GoldenEye': 292194034, 'Jumanji': 197821940}

# %% [markdown]
# 4. Get top-n movies by runtime in the form:
#
# `{'movie title': runtime}`.
#
# > Sorted descendingly.

# %%
n = 5
# %timeit links.longest(n)
print(links.longest(n))
# Out:
# 22.5 s ± 1.65 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# {'Nixon': 192, 'Casino': 178, 'Heat': 170, 'Sense and Sensibility': 136, 'Assassins': 133}

# %% [markdown]
# 5. Get top-n movies by cost per minute:
#
# `{'movie titles': cost_per_minute}`.
#
# > Sort it by the division descendingly.

# %%
n = 5
# %timeit links.top_cost_per_minute(n)
print(links.top_cost_per_minute(n))
# Out:
# 21.9 s ± 2.72 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# {'Cutthroat Island': 790322.58, 'Jumanji': 625000.0, 'Money Train': 618181.82, 'The American President': 543859.65, 'GoldenEye': 461538.46}

# %% [markdown]
# ## **Tags**

# %% [markdown]
# 0. Get tags data from `tags.csv`

# %%
# %timeit movielens_analysis.Tags('tags.csv')
tags = movielens_analysis.Tags('tags.csv')
# Out:
# 7.75 ms ± 1.7 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# 1. Get top-n tags with most words inside in the form:
#
# `{'tag': number of words inside the tag}`.
#
# > Sorted descendingly.

# %%
n = 5
# %timeit tags.most_words(n)
print(tags.most_words(n))
# Out:
# 777 µs ± 171 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# {'Something for everyone in this one... saw it without and plan on seeing it with kids!': 16, 'the catholic church is the most corrupt organization in history': 10, 'villain nonexistent or not needed for good story': 8, '06 Oscar Nominated Best Movie - Animation': 7, 'It was melodramatic and kind of dumb': 7}

# %% [markdown]
# 2. Get top-n longest tags.
#
# > Sorted descendingly.

# %%
n = 5
# %timeit tags.longest(n)
print(tags.longest(n))
# Out:
# 283 µs ± 9.01 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# ['Something for everyone in this one... saw it without and plan on seeing it with kids!', 'the catholic church is the most corrupt organization in history', 'villain nonexistent or not needed for good story', 'r:disturbing violent content including rape', '06 Oscar Nominated Best Movie - Animation']

# %% [markdown]
# 3. Get the intersection between top-n tags with most words inside and top-n longest tags in terms of the number of characters.

# %%
n = 5
# %timeit tags.most_words_and_longest(n)
print(tags.most_words_and_longest(n))
print('Number of coincidences: ', len(tags.most_words_and_longest(n)))
# Out:
# 943 µs ± 31.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# {'06 Oscar Nominated Best Movie - Animation', 'the catholic church is the most corrupt organization in history', 'villain nonexistent or not needed for good story', 'Something for everyone in this one... saw it without and plan on seeing it with kids!'}
# Number of coincidences:  4

# %% [markdown]
# 4. Get the most popular tags in the form: `{'tags': counts}`.
#
# > Sorted descendingly.

# %%
n = 5
# %timeit tags.most_popular(n)
print(tags.most_popular(n))
# Out:
# 436 µs ± 5.31 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# {'In Netflix queue': 131, 'atmospheric': 36, 'superhero': 24, 'thought-provoking': 24, 'funny': 23}

# %% [markdown]
# 5. Get all unique tags that include the word given.
#
# > Sorted by tag names alphabetically.

# %%
word = 'Netflix'
# %timeit tags.tags_with(word)
print(tags.tags_with(word))
# Out:
# 233 µs ± 9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# ['In Netflix queue', 'No DVD at Netflix', 'Not available from Netflix']

# %% [markdown]
# ## **Ratings**

# %%
ratings = movielens_analysis.Ratings('./ratings.csv', './movies.csv')
movies = ratings.Movies(ratings.data)
users = ratings.Users(ratings.data)

# %% [markdown]
# 0. Data: ratings + movies

# %%
# %timeit ratings_data = ratings.data
print(ratings.data[:100])
# Out:
# 19.9 ns ± 0.766 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
# ...

# %% [markdown]
# 1. Get number of movies by year in the form:
#
# `{year: number of movies}`
#
# >Sorted ascendingly.

# %%
# %timeit movies.dist_by_year()
print(movies.dist_by_year())
# Out:
# 133 ms ± 33.4 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# {1996: 6040, 1997: 1916, 1998: 507, 1999: 2439, 2000: 10061, 2001: 3922, 2002: 3478, 2003: 4014, 2004: 3279, 2005: 5813, 2006: 4059, 2007: 7114, 2008: 4351, 2009: 4158, 2010: 2301, 2011: 1690, 2012: 4656, 2013: 1664, 2014: 1439, 2015: 6616, 2016: 6703, 2017: 8198, 2018: 6418}

# %% [markdown]
# 2. Get the number of each of the ratings in the form:
#
# `{rating: number of ratings}`
#
# > Sorted ascendingly.

# %%
# %timeit movies.dist_by_rating()
print(movies.dist_by_rating())
# Out:
# 34.2 ms ± 910 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# {0.5: 1370, 1.0: 2811, 1.5: 1791, 2.0: 7551, 2.5: 5550, 3.0: 20047, 3.5: 13136, 4.0: 26818, 4.5: 8551, 5.0: 13211}

# %% [markdown]
# 3. Get top-n movies by the number of ratings in the form:
#
# `{title: number of ratings}`
#
# > Sorted descendingly.

# %%
n = 5
# %timeit movies.top_by_num_of_ratings(n=n)
print(movies.top_by_num_of_ratings(n=n))
# Out:
# 28.2 ms ± 1.29 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# {'Forrest Gump (1994)': 329, '"Shawshank Redemption': 317, 'Pulp Fiction (1994)': 307, '"Silence of the Lambs': 279, '"Matrix': 278}

# %% [markdown]
# 4. Get top-n movies by the average or median of the ratings in the form:
#
# `{title: average or median of the ratings}`
# > Sorted descendingly order by median or average .
#
# > metric options: 'median', 'average'

# %%
n = 500
metric = 'average'
# %timeit movies.top_by_ratings(n=n, metric=metric)
print(movies.top_by_ratings(n=n, metric=metric))
# Out:
# 89 ms ± 20.4 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ...

# %% [markdown]
# 5. Get top-n movies by the variance of the ratings in the form:
#
# `{title: variance of the ratings}`
#
# > Sorted descendingly

# %%
n = 50
# %timeit movies.top_controversial(n=n)
print(movies.top_controversial(n=n))
# Out:
# 98.6 ms ± 12.8 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ...

# %% [markdown]
# ### **Users**

# %% [markdown]
# 0. Get top-n of users by the number of ratings in the form:
#
# `{'userId': number of ratings}`
#
# > Sorted descendingly order by number of ratings

# %%
n = 50
# %timeit users.top_by_num_of_ratings(n=n)
print(users.top_by_num_of_ratings(n=n))
# Out:
# 19.8 ms ± 3.3 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'414': 2698, '599': 2478, '474': 2108, '448': 1864, '274': 1346, '610': 1302, '68': 1260, '380': 1218, '606': 1115, '288': 1055, '249': 1046, '387': 1027, '182': 977, '307': 975, '603': 943, '298': 939, '177': 904, '318': 879, '232': 862, '480': 836, '608': 831, '600': 763, '483': 728, '590': 728, '105': 722, '19': 703, '305': 677, '489': 648, '111': 646, '438': 635, '217': 613, '140': 608, '477': 600, '555': 578, '91': 575, '28': 570, '219': 528, '534': 520, '89': 518, '64': 517, '226': 507, '561': 505, '18': 502, '525': 500, '57': 476, '381': 474, '368': 469, '509': 467, '469': 465, '560': 458}

# %% [markdown]
# 1. Get top-n users by the average or median of the ratings made by them in the form:
#
# `{'userId': average or median of the ratings made by them}`
# > Sorted descendingly order by average or median
#
# > metric options: 'median', 'average'

# %%
n = 15
metric='average'
# %timeit users.top_by_ratings(n=n, metric=metric)
print(users.top_by_ratings(n=n, metric=metric))
# Out:
# 32.4 ms ± 817 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# {'53': 5.0, '251': 4.87, '515': 4.85, '25': 4.81, '30': 4.74, '523': 4.69, '348': 4.67, '171': 4.63, '452': 4.56, '43': 4.55, '122': 4.55, '371': 4.55, '441': 4.52, '400': 4.51, '52': 4.48}

# %% [markdown]
#  Get top-n users with the biggest variance of their ratings in the form:
#
# `{'userId': variance of the ratings}`
#
# > Sorted descendingly order by variance

# %%
n = 15
# %timeit users.top_controversial(n=n)
print(users.top_controversial(n=n))
# Out:
# 61 ms ± 14.4 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# {'3': 4.26, '461': 3.1, '55': 3.09, '259': 2.94, '329': 2.92, '502': 2.76, '175': 2.75, '598': 2.7, '393': 2.61, '138': 2.44, '160': 2.39, '22': 2.36, '418': 2.25, '308': 2.23, '360': 2.23}

# %% [markdown]
# ## **Movies**

# %% [markdown]
# 0. Loading data

# %%
movies = movielens_analysis.Movies("./movies.csv")
# %timeit movies.get_all()
all_movies = movies.get_all()
print(all_movies[:100])
# Out:
# 62.4 ns ± 10.7 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
# ...

# %% [markdown]
# 1. Distribution by year

# %%
# %timeit movies.dist_by_release()
release_distribution = movies.dist_by_release()
print(release_distribution)
# Out:
# 7.06 ms ± 92 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# ...

# %% [markdown]
# 2. Genre distribution

# %%
# %timeit movies.dist_by_genres()
genre_distribution = movies.dist_by_genres()
print(genre_distribution)
# Out:
# 12.1 ms ± 2.14 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'Drama': 4361, 'Comedy': 3756, 'Thriller': 1894, 'Action': 1828, 'Romance': 1596, 'Adventure': 1263, 'Crime': 1199, 'Sci-Fi': 980, 'Horror': 978, 'Fantasy': 779, 'Children': 664, 'Animation': 611, 'Mystery': 573, 'Documentary': 440, 'War': 382, 'Musical': 334, 'Western': 167, 'IMAX': 158, 'Film-Noir': 87}

# %% [markdown]
# 3. Top N films by number of genres

# %%
# %timeit movies.most_genres(10)
top_movies = movies.most_genres(10)
print(top_movies)
# Out:
# 9.4 ms ± 1.87 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'Rubber (2010)': 10, 'Patlabor: The Movie (Kidô keisatsu patorebâ: The Movie) (1989)': 8, 'Mulan (1998)': 7, 'Who Framed Roger Rabbit? (1988)': 7, 'Osmosis Jones (2001)': 7, 'Interstate 60 (2002)': 7, 'Robots (2005)': 7, 'Pulse (2006)': 7, 'Aqua Teen Hunger Force Colon Movie Film for Theaters (2007)': 7, 'Enchanted (2007)': 7}
